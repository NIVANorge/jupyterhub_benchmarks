# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

plt.style.use("ggplot")

# %% [markdown]
# # JupyterHub benchmarking
#
# ## Plot results

# %%
xl_path = r"../results/hub_benchmarks.xlsx"
df = pd.read_excel(xl_path)
df.dropna(how='any', inplace=True)
df.head()
# Out:
#   Test                         Name  Trial  Hub  Value  \
# 0    1  Write to shared disk (MB/s)      1  Old  145.0
# 1    1  Write to shared disk (MB/s)      2  Old  164.0
# 2    1  Write to shared disk (MB/s)      3  Old  164.0
# 3    1  Write to shared disk (MB/s)      4  Old  161.0
# 4    1  Write to shared disk (MB/s)      5  Old  203.0
#
#                                              Details
# 0  dd bs=1M count=1024 if=/dev/zero of=test conv=...
# 1  dd bs=1M count=1024 if=/dev/zero of=test conv=...
# 2  dd bs=1M count=1024 if=/dev/zero of=test conv=...
# 3  dd bs=1M count=1024 if=/dev/zero of=test conv=...
# 4  dd bs=1M count=1024 if=/dev/zero of=test conv=...

# %%
sn.catplot(
    data=df,
    x="Hub",
    y="Value",
    col="Name",
    kind="bar",
    col_wrap=3,
    aspect=1.5,
    height=3,
    sharex=False,
    sharey=False,
    legend_out=False,
)

png_path = r"../results/test_results.png"
plt.savefig(png_path, dpi=200)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:3201: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)
